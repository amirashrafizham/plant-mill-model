# %% [markdown]
# ## Load Data

# %%
# Load the Excel file data in sheet number 2 using pandas
import pandas as pd
pd.set_option("display.max_columns", None)

# Load the Excel file data in sheet number 2 using pandas, use the first row as the column names
df = pd.read_excel("Case Study for Data Scientist.xlsx", sheet_name="Sheet1", header=0)
df.head()
# Out:
#    Day       Date Region Mill Code Mill Type  Actual OER %  \
# 0  Wed 2020-01-01    R01      Z001        IP          0.00
# 1  Thu 2020-01-02    R01      Z001        IP         22.27
# 2  Fri 2020-01-03    R01      Z001        IP         22.55
# 3  Sat 2020-01-04    R01      Z001        IP         22.12
# 4  Sun 2020-01-05    R01      Z001        IP          0.00
#
#    Crop Freshness Score     Ripe %  Long Stalk %  Rat Damage %  \
# 0            300.000000  95.157670      1.241942      4.734563
# 1            289.458286  95.430159      1.859710      3.931418
# 2            262.890977  94.617481      1.514098      3.568296
# 3            262.653835  95.404031      1.457055      4.809152
# 4                   NaN        NaN           NaN           NaN
#
#    Loose Fruits %  Rainfall (mm)  Age Profile (years)  Total Oil Losses %  \
# 0        6.833731       0.000000            15.721261            0.000000
# 1        7.475889       3.342912            13.950932            1.387521
# 2        7.416632      24.355107            13.322048            1.484348
# 3        7.225248       1.208765            14.120394            1.364690
# 4        0.000000            NaN                  NaN            0.000000
#
#    Downtime %  FFB Processed (MT)   Seed A %  Seed B %  Other Seeds %  \
# 0    0.000000               0.000  31.114312       0.0      68.885688
# 1    0.254744             648.373  39.927122       0.0      60.072878
# 2    0.058243             530.021  37.392953       0.0      62.607047
# 3    0.099324             702.527  33.681927       0.0      66.318073
# 4    0.000000               0.000        NaN       NaN            NaN
#
#    Coastal %   Inland %
# 0  49.290868  50.709132
# 1  46.188086  53.811914
# 2  45.361864  54.638136
# 3  51.698756  48.301244
# 4        NaN        NaN

# %%
categorical_features = df.select_dtypes(include=['object']).columns
print(categorical_features)
print(len(categorical_features))

numerical_features = df.select_dtypes(include=['int64', 'float64']).columns
#numerical_features = numerical_features.drop('Actual OER %')
print(numerical_features)
print(len(numerical_features))

label = 'Actual OER %'
# Out:
# Index(['Day', 'Region', 'Mill Code', 'Mill Type'], dtype='object')
# 4
# Index(['Actual OER %', 'Crop Freshness Score', 'Ripe %', 'Long Stalk %',
#        'Rat Damage %', 'Loose Fruits %', 'Rainfall (mm)',
#        'Age Profile (years)', 'Total Oil Losses %', 'Downtime %',
#        'FFB Processed (MT)', 'Seed A %', 'Seed B %', 'Other Seeds %',
#        'Coastal %', 'Inland %'],
#       dtype='object')
# 16

# %% [markdown]
# ## Feature Engineering

# %%
# ZO22 is chosen as the mill code to be analyzed
zo22 = df[df['Mill Code'] == 'Z022']
# set the Date as the index
zo22 = zo22.set_index('Date')
zo22.head(10)
# Out:
#             Day Region Mill Code Mill Type  Actual OER %  \
# Date
# 2020-01-01  Wed    R04      Z022        IP         20.35
# 2020-01-02  Thu    R04      Z022        IP         20.51
# 2020-01-03  Fri    R04      Z022        IP         21.30
# 2020-01-04  Sat    R04      Z022        IP         20.15
# 2020-01-05  Sun    R04      Z022        IP          0.00
# 2020-01-06  Mon    R04      Z022        IP         21.83
# 2020-01-07  Tue    R04      Z022        IP         21.74
# 2020-01-08  Wed    R04      Z022        IP         21.52
# 2020-01-09  Thu    R04      Z022        IP         21.74
# 2020-01-10  Fri    R04      Z022        IP         21.65
#
#             Crop Freshness Score     Ripe %  Long Stalk %  Rat Damage %  \
# Date
# 2020-01-01            296.777917  77.031644      2.207673     14.028534
# 2020-01-02            267.854639  85.720531      2.248377     14.948637
# 2020-01-03            267.452850  85.708630      1.381812     13.041987
# 2020-01-04            274.061410  85.165413      2.599849     12.903222
# 2020-01-05                   NaN        NaN           NaN           NaN
# 2020-01-06            300.000000  83.111808      2.594010     10.559147
# 2020-01-07            269.436603  83.380961      2.157992     12.599063
# 2020-01-08            273.798453  81.619159      2.041962     13.342093
# 2020-01-09            272.847626  84.788061      1.772059     12.646855
# 2020-01-10            276.869298  85.052589      2.072148     11.735895
#
#             Loose Fruits %  Rainfall (mm)  Age Profile (years)  \
# Date
# 2020-01-01        5.919710       0.287178            13.029043
# 2020-01-02        8.655752       3.334981            12.278802
# 2020-01-03        6.562387       3.191424            11.611554
# 2020-01-04        6.495598       0.000000            11.714539
# 2020-01-05        0.000000            NaN                  NaN
# 2020-01-06        7.809587      13.234215            12.856042
# 2020-01-07        7.279364       0.552664            13.869995
# 2020-01-08        7.328390       0.450991            14.674018
# 2020-01-09        6.810884       0.054258            14.190942
# 2020-01-10        9.014769       0.000000            12.102301
#
#             Total Oil Losses %  Downtime %  FFB Processed (MT)   Seed A %  \
# Date
# 2020-01-01            1.261184    0.125803             511.405   4.472428
# 2020-01-02            1.464456    0.066092             518.319   4.966389
# 2020-01-03            1.252361    0.178279             435.348   6.638849
# 2020-01-04            1.182214    0.036554             549.164   8.743589
# 2020-01-05            0.000000    0.000000               0.000        NaN
# 2020-01-06            1.493988    0.146752             537.546   5.553637
# 2020-01-07            1.453156    0.097292             595.787   2.693918
# 2020-01-08            1.529618    0.127397             628.274   1.721227
# 2020-01-09            1.320507    0.107420             589.103  10.251145
# 2020-01-10            1.270278    0.153777             558.507   2.412821
#
#             Seed B %  Other Seeds %  Coastal %  Inland %
# Date
# 2020-01-01       0.0      95.527572        0.0     100.0
# 2020-01-02       0.0      95.033611        0.0     100.0
# 2020-01-03       0.0      93.361151        0.0     100.0
# 2020-01-04       0.0      91.256411        0.0     100.0
# 2020-01-05       NaN            NaN        NaN       NaN
# 2020-01-06       0.0      94.446363        0.0     100.0
# 2020-01-07       0.0      97.306082        0.0     100.0
# 2020-01-08       0.0      98.278773        0.0     100.0
# 2020-01-09       0.0      89.748855        0.0     100.0
# 2020-01-10       0.0      97.587179        0.0     100.0

# %% [markdown]
# ## Model Training

# %%
# Train a linear regression model
from sklearn.linear_model import LinearRegression, Ridge, Lasso
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
from sklearn.metrics import mean_absolute_error
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from lightgbm import LGBMRegressor
from sklearn.svm import SVC
from sklego.meta import ZeroInflatedRegressor
from sklearn.ensemble import RandomForestClassifier

lr = LinearRegression()
ridge = Ridge()
lasso = Lasso()
lgbm = LGBMRegressor()
svm = SVC()



zir = ZeroInflatedRegressor(classifier=RandomForestClassifier(), regressor=LGBMRegressor())

def train_model(model, X_train, y_train, X_test, y_test, X, y):
    model.fit(X_train, y_train)

    # Make predictions
    y_pred = model.predict(X_test)

    # Evaluate the model
    mse = mean_squared_error(y_test, y_pred)
    print("Mean Squared Error:", mse)

    # Calculate the R^2 score
    r2 = r2_score(y_test, y_pred)
    print("R^2 Score:", r2)

    # Calculate the RMSE
    rmse = mse ** 0.5
    print("Root Mean Squared Error:", rmse)

    # Calculate the MAE
    mae = mean_absolute_error(y_test, y_pred)
    print("Mean Absolute Error:", mae)

    # Calculate the MAPE
    mape = np.mean(np.abs((y_test - y_pred) / y_test)) * 100
    print("Mean Absolute Percentage Error:", mape)

    # Plot the predicted vs actual values
    plt.scatter(y_test, y_pred)
    plt.xlabel("Actual OER %")
    plt.ylabel("Predicted OER %")
    plt.title("Actual OER % vs Predicted OER %")
    plt.plot([0, 100], [0, 100], color='r', linestyle='--')
    plt.show()

    # Calculate the residuals
    residuals = y_test - y_pred

    # Plot the residuals
    # plt.scatter(y_test, residuals)
    # plt.xlabel("Actual OER %")
    # plt.ylabel("Residuals")
    # plt.title("Actual OER % vs Residuals")
    # plt.axhline(y=0, color='r', linestyle='--')
    # plt.show()

    # Plot the residuals vs predicted values
    plt.scatter(y_pred, residuals)
    plt.xlabel("Predicted OER %")
    plt.ylabel("Residuals")
    plt.title("Predicted OER % vs Residuals")
    plt.axhline(y=0, color='r', linestyle='--')
    plt.show()

    # Plot the residuals distribution
    sns.histplot(residuals, kde=True)
    plt.xlabel("Residuals")
    plt.ylabel("Frequency")
    plt.title("Residuals Distribution")
    plt.show()

    inference_df = pd.DataFrame()
    inference_df['Predicted OER %'] = model.predict(X)
    inference_df['Actual OER %'] = y.values
    inference_df['Residuals'] = inference_df['Actual OER %'] - inference_df['Predicted OER %']
    inference_df['Date'] = y.index

    # split the data into 2021, 2022, 2023, and 2024
    inference_df['Year'] = inference_df['Date'].dt.year

    # for 2024
    inference_df_2024 = inference_df[inference_df['Year'] == 2024]
    X_train_2024 = X_train[X_train.index.year == 2024]
    X_test_2024 = X_test[X_test.index.year == 2024]
    # using matplotlib
    plt.plot(inference_df_2024['Date'], inference_df_2024['Actual OER %'], label='Actual OER %')
    plt.plot(inference_df_2024['Date'], inference_df_2024['Predicted OER %'], label='Predicted OER %')
    for i in X_train_2024.index:
        plt.axvline(x=i, color='r', linestyle='-', alpha=0.1)
    plt.xlabel('Date')
    plt.ylabel('OER %')
    plt.title('Training Region')
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

    # using matplotlib
    plt.plot(inference_df_2024['Date'], inference_df_2024['Actual OER %'], label='Actual OER %')
    plt.plot(inference_df_2024['Date'], inference_df_2024['Predicted OER %'], label='Predicted OER %')
    for i in X_test_2024.index:
        plt.axvline(x=i, color='g', linestyle='-', alpha=0.1)
    plt.xlabel('Date')
    plt.ylabel('OER %')
    plt.title('Testing Region')
    plt.xticks(rotation=45)
    plt.legend()
    plt.show()

    # using plotly
    import plotly.express as px
    fig = px.line(inference_df, x='Date', y=['Actual OER %', 'Predicted OER %'])
    fig.show()

    return model

# %%
## Split the data into training and testing sets
from sklearn.model_selection import train_test_split

# Index(['Crop Freshness Score', 'Ripe %', 'Long Stalk %', 'Rat Damage %',
#       'Loose Fruits %', 'Rainfall (mm)', 'Age Profile (years)',
#       'Total Oil Losses %', 'Downtime %', 'FFB Processed (MT)', 'Seed A %',
#       'Seed B %', 'Other Seeds %', 'Coastal %', 'Inland %'],
#      dtype='object')

zo22_df = zo22.copy()

# drop null values in zo22_df (R^2 Score: 0.63, rmse: 3.40)
zo22_df = zo22_df.dropna()

# refined_features = numerical_features.drop([label, 'Other Seeds %', 'Seed B %', 'Inland %', 'Total Oil Losses %'])
# refined_features = [
#    "FFB Processed (MT)",
#    "Crop Freshness Score",
#    "Ripe %",
#    "Loose Fruits %",
# ]
refined_features = numerical_features.drop([label])
# filter the features

X = zo22_df[refined_features]
print(X.columns)

X = zo22_df[numerical_features].drop(label, axis=1)
y = zo22_df[label]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)
# Out:
# Index(['Crop Freshness Score', 'Ripe %', 'Long Stalk %', 'Rat Damage %',
#        'Loose Fruits %', 'Rainfall (mm)', 'Age Profile (years)',
#        'Total Oil Losses %', 'Downtime %', 'FFB Processed (MT)', 'Seed A %',
#        'Seed B %', 'Other Seeds %', 'Coastal %', 'Inland %'],
#       dtype='object')

# %%
lgbm_trained =train_model(lgbm, X_train, y_train, X_test, y_test, X, y)
# Out:
# [LightGBM] [Warning] Found whitespace in feature_names, replace with underlines
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.016992 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3060
# [LightGBM] [Info] Number of data points in the train set: 1082, number of used features: 12
# [LightGBM] [Info] Start training from score 18.940813
# Mean Squared Error: 0.6037765063666579
# R^2 Score: 0.9798146062554332
# Root Mean Squared Error: 0.7770305697761561
# Mean Absolute Error: 0.5849271945893653
# Mean Absolute Percentage Error: inf

# %%
ridge_trained = train_model(ridge, X_train, y_train, X_test, y_test, X, y)
# Out:
# Mean Squared Error: 8.897251515255464
# R^2 Score: 0.7025480071084245
# Root Mean Squared Error: 2.9828260953759043
# Mean Absolute Error: 2.3238890010587916
# Mean Absolute Percentage Error: inf

# %%
# using the ZeroInflatedRegressor
zir_trained = train_model(zir, X_train, y_train, X_test, y_test, X, y)
# Out:
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/_tags.py:354: FutureWarning:
#
# The LGBMRegressor or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/_tags.py:354: FutureWarning:
#
# The LGBMRegressor or classes from which it inherits use `_get_tags` and `_more_tags`. Please define the `__sklearn_tags__` method, or inherit from `sklearn.base.BaseEstimator` and/or other appropriate mixins such as `sklearn.base.TransformerMixin`, `sklearn.base.ClassifierMixin`, `sklearn.base.RegressorMixin`, and `sklearn.base.OutlierMixin`. From scikit-learn 1.7, not defining `__sklearn_tags__` will raise an error.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# [LightGBM] [Info] Auto-choosing col-wise multi-threading, the overhead of testing was 0.000340 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3045
# [LightGBM] [Info] Number of data points in the train set: 990, number of used features: 12
# [LightGBM] [Info] Start training from score 20.700970
# Mean Squared Error: 0.6065953288717028
# R^2 Score: 0.9797203676728444
# Root Mean Squared Error: 0.7788423003867361
# Mean Absolute Error: 0.578086000940222
# Mean Absolute Percentage Error: 3.0180080979059345
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %% [markdown]
# ## Analyze Model

# %%
# Separate the Actual OER % > 1 and Actual OER % < 1
X_train_1 = X_train[y_train > 1]
y_train_1 = y_train[y_train > 1]
X_test_1 = X_test[y_test > 1]
y_test_1 = y_test[y_test > 1]

X_train_2 = X_train[y_train < 1]
y_train_2 = y_train[y_train < 1]
X_test_2 = X_test[y_test < 1]
y_test_2 = y_test[y_test < 1]


# Define a prediction function
def predict(X):
    return zir_trained.predict(X)


import shap
# Use SHAP Kernel Explainer to explain the model's predictions for the Actual OER % > 1
explainer = shap.KernelExplainer(predict, shap.sample(X_train, 50))
# Out:
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.

# %%
shap_values = explainer(X_train)
shap.summary_plot(shap_values, X_train)
# Out:
#   0%|          | 0/1082 [00:00<?, ?it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   0%|          | 1/1082 [00:00<12:35,  1.43it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   0%|          | 2/1082 [00:01<11:48,  1.52it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   0%|          | 3/1082 [00:01<11:14,  1.60it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   0%|          | 4/1082 [00:02<11:03,  1.62it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   0%|          | 5/1082 [00:03<11:00,  1.63it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|          | 6/1082 [00:03<11:04,  1.62it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|          | 7/1082 [00:04<10:26,  1.72it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|          | 8/1082 [00:04<10:29,  1.71it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|          | 9/1082 [00:05<10:13,  1.75it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|          | 10/1082 [00:05<09:54,  1.80it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|          | 11/1082 [00:06<10:07,  1.76it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|          | 12/1082 [00:07<10:20,  1.72it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|          | 13/1082 [00:07<10:26,  1.71it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|▏         | 14/1082 [00:08<10:28,  1.70it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|▏         | 15/1082 [00:08<10:32,  1.69it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   1%|▏         | 16/1082 [00:09<10:31,  1.69it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 17/1082 [00:10<10:34,  1.68it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 18/1082 [00:10<10:49,  1.64it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 19/1082 [00:11<10:46,  1.65it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 20/1082 [00:11<10:56,  1.62it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 21/1082 [00:12<10:44,  1.65it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 22/1082 [00:13<10:46,  1.64it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 23/1082 [00:13<10:06,  1.75it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 24/1082 [00:14<10:21,  1.70it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 25/1082 [00:14<10:18,  1.71it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 26/1082 [00:15<10:40,  1.65it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   2%|▏         | 27/1082 [00:16<10:25,  1.69it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 28/1082 [00:16<10:26,  1.68it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 29/1082 [00:17<10:21,  1.69it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 30/1082 [00:17<10:22,  1.69it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 31/1082 [00:18<10:26,  1.68it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 32/1082 [00:19<10:29,  1.67it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 33/1082 [00:19<10:14,  1.71it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 34/1082 [00:20<10:24,  1.68it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 35/1082 [00:20<10:19,  1.69it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 36/1082 [00:21<10:28,  1.67it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   3%|▎         | 37/1082 [00:22<10:22,  1.68it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▎         | 38/1082 [00:22<10:20,  1.68it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▎         | 39/1082 [00:23<10:23,  1.67it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▎         | 40/1082 [00:23<10:23,  1.67it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▍         | 41/1082 [00:24<10:22,  1.67it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▍         | 42/1082 [00:24<09:46,  1.77it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▍         | 43/1082 [00:25<09:50,  1.76it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▍         | 44/1082 [00:26<10:07,  1.71it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▍         | 45/1082 [00:26<10:16,  1.68it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▍         | 46/1082 [00:27<10:24,  1.66it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#   4%|▍         | 47/1082 [00:27<10:15,  1.68it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# ...
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▊| 1067/1082 [10:55<00:09,  1.51it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▊| 1068/1082 [10:56<00:08,  1.59it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▉| 1069/1082 [10:56<00:08,  1.58it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▉| 1070/1082 [10:57<00:07,  1.57it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▉| 1071/1082 [10:58<00:06,  1.58it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▉| 1072/1082 [10:58<00:06,  1.51it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▉| 1073/1082 [10:59<00:05,  1.53it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▉| 1074/1082 [10:59<00:05,  1.55it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▉| 1075/1082 [11:00<00:04,  1.52it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
#  99%|█████████▉| 1076/1082 [11:01<00:03,  1.59it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 100%|█████████▉| 1077/1082 [11:01<00:03,  1.59it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 100%|█████████▉| 1078/1082 [11:02<00:02,  1.57it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 100%|█████████▉| 1079/1082 [11:03<00:01,  1.64it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 100%|█████████▉| 1080/1082 [11:03<00:01,  1.61it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 100%|█████████▉| 1081/1082 [11:04<00:00,  1.57it/s]/Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/validation.py:2739: UserWarning:
#
# X does not have valid feature names, but ZeroInflatedRegressor was fitted with feature names
#
# /Users/amirashrafizham/Desktop/PythonApps/interviews/simedarbyguthrie/.venv/lib/python3.11/site-packages/sklearn/utils/deprecation.py:151: FutureWarning:
#
# 'force_all_finite' was renamed to 'ensure_all_finite' in 1.6 and will be removed in 1.8.
#
# 100%|██████████| 1082/1082 [11:05<00:00,  1.63it/s]
